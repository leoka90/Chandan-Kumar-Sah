# %% [markdown]
# <a href="https://colab.research.google.com/github/leoka90/Chandan-Kumar-Sah/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Importing Dataset**

# %%
dataframe=pd.read_csv("/content/titanic_dataset.csv")
dataframe.head(892)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **Summary Statistics**

# %%
dataframe.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# **create histogram**

# %%
dataset = dataframe['Fare'].dropna()
plt.figure(figsize=(15, 10))
plt.hist(fare, bins=30, color='blue', edgecolor='black')
plt.title('Histogram for Fare')
plt.xlabel('fare')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# **Creating Boxpplot**

# %%
X = dataframe.select_dtypes(include='number').dropna()
fig, ax = plt.subplots(figsize=(15, 10))
sns.boxplot(data=X, ax=ax)
ax.set_title("Boxplot of Numerical Features Before Removing Outliers")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **use pairplot**

# %%
sns.pairplot(dataframe[['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']])
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(dataframe.select_dtypes(include=['int64', 'float64']).corr(), annot=True)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# **Identifying Pattern,Trends or anomolies**

# %%
sns.histplot(data=dataframe, x='Age', hue='Survived', kde=True)
plt.title("Age Distribution by Survival")
plt.show()

# %%
sns.histplot(data=dataframe, x='Fare', hue='Survived', bins=30, kde=True)
plt.title("Fare Distribution by Survival")
plt.show()

# %%
dataframe['FamilySize'] = dataframe['SibSp'] + dataframe['Parch']
sns.countplot(data=dataframe, x='FamilySize', hue='Survived')
plt.title("Survival by Family Size")
plt.show()

# %% [markdown]
# **Feature-level Inferences**

# %%
plt.figure(figsize=(15, 15))
sns.histplot(data=dataframe, x='Age', hue='Survived', kde=True)
plt.title("Age Distribution by Survival")
plt.show()

# %%
plt.figure(figsize=(15, 15))
sns.histplot(data=dataframe, x='Fare', hue='Survived', kde=True)
plt.title("Fare Distribution by Survival")
plt.show()

# %%
dataframe['FamilySize'] = dataframe['SibSp'] + dataframe['Parch']
plt.figure(figsize=(7, 4))
sns.countplot(data=dataframe, x='FamilySize', hue='Survived')
plt.title("Survival by Family Size")
plt.show()
