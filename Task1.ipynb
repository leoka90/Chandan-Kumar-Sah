# %% [markdown]
# <a href="https://colab.research.google.com/github/leoka90/Chandan-Kumar-Sah/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing librarires**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# **Importing dataset**

# %%
#imporing dataset
dataframe=pd.read_csv("/content/titanic_dataset.csv")
dataframe.head(892)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **Data type**

# %%
dataframe.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
dataframe.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# **Handling Missing Values**

# %%
dataframe.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sns.distplot(dataframe.PassengerId)
# Out:
# <ipython-input-14-63c7f92be330>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataframe.PassengerId)
# <Axes: xlabel='PassengerId', ylabel='Density'>

# %%
sns.distplot(dataframe.Survived)
# Out:
# <ipython-input-15-71e37fc70650>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataframe.Survived)
# <Axes: xlabel='Survived', ylabel='Density'>

# %%
sns.distplot(dataframe.Pclass)
# Out:
# <ipython-input-16-005b527bbdfb>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataframe.Pclass)
# <Axes: xlabel='Pclass', ylabel='Density'>

# %%
sns.distplot(dataframe.Age)
# Out:
# <ipython-input-17-42ec12eb0382>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataframe.Age)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(dataframe.SibSp)
# Out:
# <ipython-input-19-eb6db573c304>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataframe.SibSp)
# <Axes: xlabel='SibSp', ylabel='Density'>

# %%
sns.distplot(dataframe.Parch)
# Out:
# <ipython-input-20-95894e3b9363>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataframe.Parch)
# <Axes: xlabel='Parch', ylabel='Density'>

# %%
sns.distplot(dataframe.Fare)
# Out:
# <ipython-input-21-13caa65ca175>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataframe.Fare)
# <Axes: xlabel='Fare', ylabel='Density'>

# %% [markdown]
# **Data Imputation**

# %%
#Data Imputation
dataframe["Age"] = dataframe["Age"].fillna(dataframe["Age"].median())
dataframe["Fare"] = dataframe["Fare"].fillna(dataframe["Fare"].median())
dataframe["Embarked"] = dataframe["Embarked"].fillna(dataframe["Embarked"].mode()[0])
dataframe["Cabin"] = dataframe["Cabin"].fillna("Unknown")

# %% [markdown]
# **Converting Categorical Feature Into Numerical**

# %%
#converting categorical features into numerical
categorical_cols = dataframe.select_dtypes(include=['object']).columns
print("Categorical columns:", list(categorical_cols))
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
if 'Sex' in dataframe.columns:
    dataframe['Sex'] = label_encoder.fit_transform(dataframe['Sex'])
one_hot_cols = ['Embarked', 'Cabin', 'Pclass']
one_hot_cols = [col for col in one_hot_cols if col in dataframe.columns]
dataframe = pd.get_dummies(dataframe, columns=one_hot_cols, drop_first=True)
print("\nNew columns after encoding:")
print(dataframe.columns.tolist())
# Out:
# Categorical columns: ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']
#
# New columns after encoding:
# ...

# %% [markdown]
# **Normalize the Numerical features**

# %%
#normalize the numerical features
from sklearn.preprocessing import MinMaxScaler
numerical_cols = dataframe.select_dtypes(include=['number']).columns
scaler = MinMaxScaler()
dataframe[numerical_cols] = scaler.fit_transform(dataframe[numerical_cols])
print(dataframe[numerical_cols].head())
# Out:
#    PassengerId  Survived  Sex       Age  SibSp  Parch      Fare
# 0     0.000000       0.0  1.0  0.271174  0.125    0.0  0.014151
# 1     0.001124       1.0  0.0  0.472229  0.125    0.0  0.139136
# 2     0.002247       1.0  0.0  0.321438  0.000    0.0  0.015469
# 3     0.003371       1.0  0.0  0.434531  0.125    0.0  0.103644
# 4     0.004494       0.0  1.0  0.434531  0.000    0.0  0.015713

# %% [markdown]
# **Visualize Boxplots for Outliers**

# %%
#visualize boxplots for outliers
X = dataframe.select_dtypes(include='number').dropna()
fig, ax = plt.subplots(figsize=(15, 10))
sns.boxplot(data=X, ax=ax)
ax.set_title("Boxplot of Numerical Features Before Removing Outliers")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Removal of Outliers**

# %%
#removing outliers
Q1 = X.quantile(0.25)
Q3 = X.quantile(0.75)
IQR = Q3 - Q1
mask = ~((X < (Q1 - 1.5 * IQR)) | (X > (Q3 + 1.5 * IQR))).any(axis=1)
X_clean = X[mask]
fig, ax = plt.subplots(figsize=(15, 10))
sns.boxplot(data=X_clean, ax=ax)
ax.set_title("Boxplot After Removing Outliers (IQR Method)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
print("Original shape:", X.shape)
print("After outlier removal:", X_clean.shape)
# Out:
# Original shape: (891, 7)
# After outlier removal: (577, 7)
